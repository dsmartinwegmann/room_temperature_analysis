# %% [markdown]
# # Author Information

# %% [markdown]
# Author: Martin Wegmann
#
# Email: martin.wegmann@unibe.ch

# %% [markdown]
# ### Sub header

# %% [markdown]
# * list item 1
# * list item 2
# * list item 3

# %% [markdown]
# # Analysis Start

# %%
room_temperature=34/3

# %%
room_temperature
# Out:
# 11.333333333333334

# %%
room_temperature
